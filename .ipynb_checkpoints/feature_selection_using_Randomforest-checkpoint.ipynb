# %% [markdown]
# '''Random forests are one the most popular machine learning algorithms.
# They are so successful because they are so successdful because they provide in generala good predictive performance,
# low overfitting , and easy interpretability.
# This interpretability is giben by the fact that it is straightforward to derive the importance of each varable on the tree deciion.
# in other words it is easy to compute how much each variable is contributing to the decision'''

# %%
# libraries import 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('C:\\Users\\avina\\Desktop\\practice data set\\Proj2_Train.csv')
data.head(5)
# Out:
#    Sl No Sample ID  Age Ob_Score        BMI  Consistency_Score  \
# 0      1       DT1   20       G1  28.255713                  2
# 1      2       DT2   21       G1  29.772191                  2
# 2      3       DT3   21       G1  28.511248                  2
# 3      4       DT4   22       G1  28.772695                  2
# 4      5       DT5   22       G1  27.488918                  2
#
#    Position_Score  Effacement_Score  Dialation_Score  Station_Score  \
# 0               0                 0                1              0
# 1               0                 1                1              0
# 2               0                 1                1              0
# 3               0                 1                1              0
# 4               0                 0                1              0
#
#    Total_Bishop_Score  Cerv_Len_cms  Cerv_Wid_cms  Induction  Del_mode  \
# 0                   3           NaN           NaN          1         1
# ...

# %%
data.drop([
    'Sl No', 'Sample ID', 'Cerv_Len_cms','Cerv_Wid_cms','Unnamed: 15','Consistency_Score'
], axis=1, inplace=True)

# %%
data.head()
# Out:
#    Age Ob_Score        BMI  Position_Score  Effacement_Score  Dialation_Score  \
# 0   20       G1  28.255713               0                 0                1
# 1   21       G1  29.772191               0                 1                1
# 2   21       G1  28.511248               0                 1                1
# 3   22       G1  28.772695               0                 1                1
# 4   22       G1  27.488918               0                 0                1
#
#    Station_Score  Total_Bishop_Score  Induction  Del_mode
# 0              0                   3          1         1
# 1              0                   4          1         1
# 2              0                   4          1         1
# 3              0                   4          1         1
# 4              0                   3          1         1

# %%
final = pd.get_dummies(data,columns=['Ob_Score'],drop_first=True)

# %%
final.head()
# Out:
#    Age        BMI  Position_Score  Effacement_Score  Dialation_Score  \
# 0   20  28.255713               0                 0                1
# 1   21  29.772191               0                 1                1
# 2   21  28.511248               0                 1                1
# 3   22  28.772695               0                 1                1
# 4   22  27.488918               0                 0                1
#
#    Station_Score  Total_Bishop_Score  Induction  Del_mode  Ob_Score_G2A1  \
# 0              0                   3          1         1              0
# 1              0                   4          1         1              0
# 2              0                   4          1         1              0
# 3              0                   4          1         1              0
# 4              0                   3          1         1              0
#
#    Ob_Score_G3A2
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
y = final['Del_mode']
x = final.drop('Del_mode', axis=1)

# %%
plt.figure(figsize=(20,15))
sns.heatmap(final.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25)

# %%
sel = SelectFromModel(RandomForestClassifier(n_estimators=100))

# %%
sel.fit(x_train,y_train)
# Out:
# SelectFromModel(estimator=RandomForestClassifier())

# %%
sel.get_support()
# Out:
# array([ True,  True, False, False, False, False, False,  True, False,
#        False])

# %%
selected_feat = x_train.columns[(sel.get_support())]

# %%
len(selected_feat)
# Out:
# 3

# %%
print(selected_feat)
# Out:
# Index(['Age', 'BMI', 'Induction'], dtype='object')

# %%
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
sel.estimator_
# Out:
# RandomForestClassifier()

# %%
feature = pd.Series(sel.estimator_,feature_importances_)
feature.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4256/3232283770.py in <module>
# ----> 1 feature = pd.Series(sel.estimator_,feature_importances_)
#       2 feature.head()
#
# NameError: name 'feature_importances_' is not defined
